# %%
import sys
print(sys.executable)
# Out:
# /home/whisper/python_learn_venv/bin/python

# %%
print("ascii画一个爱心")
print("    #####         #####    ")
print(" ###########   ########### ")
print("###########################")
print("###########################")
print(" ######################### ")
print("   #####################   ")
print("     #################     ")
print("        ###########        ")
print("           #####           ")
print("             #             ")
# 画心

# %%
import pandas as pd

# 原始数据
df = pd.DataFrame({
    '区域': ['华东', '华东', '华北', '华北'],
    '城市': ['上海', '南京', '北京', '天津'],
    '销售额': [100, 80, 95, 70]
})

# 设置多级列索引
df.columns = pd.MultiIndex.from_tuples([
    ('地区', '1'),
    ('地区', '2'),
    ('销售额', '')
])


# 5. 打印结果
df
# Out:
#    地区      销售额
#     1   2
# 0  华东  上海  100
# 1  华东  南京   80
# 2  华北  北京   95
# 3  华北  天津   70
