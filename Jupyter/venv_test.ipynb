# %%
import sys
print(sys.executable)
# Out:
# /home/whisper/python_learn_venv/bin/python

# %%
print("ascii画一个爱心")
print("    #####         #####    ")
print(" ###########   ########### ")
print("###########################")
print("###########################")
print(" ######################### ")
print("   #####################   ")
print("     #################     ")
print("        ###########        ")
print("           #####           ")
print("             #             ")
# 画心
