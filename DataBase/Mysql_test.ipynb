# %%
# %load_ext sql
# %sql mysql+pymysql://root:Apoptoxin-4869@localhost/mysql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import pymysql

try:
    conn = pymysql.connect(
        host='localhost',
        user='root',
        password='Apoptoxin-4869',
        database='mysql',
        charset='utf8mb4'
    )
    print("✅ 连接成功！")
    conn.close()
except Exception as e:
    print("❌ 连接失败：", e)
# Out:
# ✅ 连接成功！
